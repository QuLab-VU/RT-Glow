# %% [markdown]
# ## Visualize DIP rate-based dose-response curves with Thunor
# Installed Thunor in a new conda environment and opened this notebook using `jupyter notebook --NotebookApp.iopub_data_rate_limit=1.0e10` according to Thunor documentation.
#
# https://core.thunor.net/en/latest/tutorial.html
#
# #### Load Thunor

# %%
import os, sys
sys.path.insert(0, os.path.abspath('../'))

import thunor
from thunor.io import read_vanderbilt_hts
from thunor.dip import dip_rates
from thunor.curve_fit import fit_params
from thunor.plots import plot_drc, plot_drc_params, plot_time_course, plot_ctrl_dip_by_plate, plot_plate_map

import pandas as pd

# %%
TOPDIR = [x for x in sys.path if 'RT-Glow' in x][0]
DATADIR = os.path.join(TOPDIR,'data')

# %%
sim_fn = 'model_H841_k3d_iter_100_cell_counts.csv'
# d = pd.read_csv(os.path.join(DATADIR,sim_fn))

# %%
d = read_vanderbilt_hts(os.path.join(DATADIR,sim_fn))

# %%
d.cell_lines
# Out:
# ['NCIH1048']

# %%
ctrl_dip_data, expt_dip_data = dip_rates(d)

# %%
d
# Out:
# HTS Dataset (1 drugs/combos, 1 cell lines)

# %%
plot_time_course(d, log_yaxis=True)
# Out:
# <div>
#
#
#             <div id="295e931d-f64a-4064-b298-a1cedc53c8b1" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("295e931d-f64a-4064-b298-a1cedc53c8b1")) {
#                     Plotly.newPlot(
#                         '295e931d-f64a-4064-b298-a1cedc53c8b1',
#                         [{"legendgroup": "__Control", "line": {"color": "black", "shape": "spline"}, "marker": {"size": 5}, "mode": "lines+markers", "name": "Control", "showlegend": true, "type": "scatter", "x": [0.0, 0.24, 0.48, 0.72, 0.96, 1.2, 1.44, 1.68, 1.92, 2.16, 2.4, 2.64, 2.88, 3.12, 3.36, 3.6, 3.84, 4.08, 4.32, 4.56, 4.8, 5.04, 5.28, 5.52, 5.76, 6.0, 6.24, 6.48, 6.72, 6.96, 7.2, 7.44, 7.68, 7.92, 8.16, 8.4, 8.64, 8.88, 9.12, 9.36, 9.6, 9.84, 10.08, 10.32, 10.56, 10.8, 11.04, 11.28, 11.52, 11.76, 12.0, 12.24, 12.48, 12.72, 12.96, 13.2, 13.44, 13.68, 13.92, 14.16, 14.4, 14.64, 14.88, 15.12, 15.36, 15.6, 15.84, 16.08, 16.32, 16.56, 16.8, 17.04, 17.28, 17.52, 17.76, 18.0, 18.24, 18.48, 18.72, 18.96, 19.2, 19.44, 19.68, 19.92, 20.16, 20.4, 20.64, 20.88, 21.12, 21.36, 21.6, 21.84, 22.08, 22.32, 22.56, 22.8, 23.04, 23.28, 23.52, 23.76, 24.0, 24.24, 24.48, 24.72, 24.96, 25.2, 25.44, 25.68, 25.92, 26.16, 26.4, 26.64, 26.88, 27.12, 27.36, 27.6, 27.84, 28.08, 28.32, 28.56, 28.8, 29.04, 29.28, 29.52, 29.76, 30.0, 30.24, 30.48, 30.72, 30.96, 31.2, 31.44, 31.68, 31.92, 32.16, 32.4, 32.64, 32.88, 33.12, 33.36, 33.6,
103.44, 103.68, 103.92, 104.16, 104.4, 104.64, 104.88, 105.12, 105.36, 105.6, 105.84, 106.08, 106.32, 106.56, 106.8, 107.04, 107.28, 107.52, 107.76, 108.0, 108.24, 108.48, 108.72, 108.96, 109.2, 109.44, 109.68, 109.92, 110.16, 110.4, 110.64, 110.88, 111.12, 111.36, 111.6, 111.84, 112.08, 112.32, 112.56, 112.8, 113.04, 113.28, 113.52, 113.76, 114.0, 114.24, 114.48, 114.72, 114.96, 115.2, 115.44, 115.68, 115.92, 116.16, 116.4, 116.64, 116.88, 117.12, 117.36, 117.6, 117.84, 118.08, 118.32, 118.56, 118.8, 119.04, 119.28, 119.52, 119.76, 120.0], "y": [0.0, 0.00472661982268896, 0.009447354868379776, 0.014166971832848319, 0.01889017532512227, 0.023612151481081867, 0.028332861955631117, 0.03304757120450219, 0.037770334535842665, 0.04248702199764409, 0.04720229448407842, 0.05191611567767751, 0.0566330711098022, 0.0613484736535419, 0.06606228833334171, 0.07077448056027436, 0.0754850 ...

# %%
ctrl_dip_data
# Out:
#                                                                 dip_rate  \
# cell_line plate                   well_id
# NCIH1048  model_H841_k3d_iter_100 model_H841_k3d_iter_100__0    0.018409
#                                   model_H841_k3d_iter_100__120  0.018409
#                                   model_H841_k3d_iter_100__144  0.018409
#                                   model_H841_k3d_iter_100__168  0.018409
#                                   model_H841_k3d_iter_100__192  0.018409
#                                   model_H841_k3d_iter_100__24   0.018409
#                                   model_H841_k3d_iter_100__48   0.018409
#                                   model_H841_k3d_iter_100__72   0.018409
#                                   model_H841_k3d_iter_100__96   0.018409
#
#                                                                 dip_fit_std_err  \
# cell_line plate                   well_id
# NCIH1048  model_H841_k3d_iter_100 model_H841_k3d_iter_100__0           0.000019
#                                   model_H841_k3d_iter_100__120         0.000019
#                                   model_H841_k3d_iter_100__144         0.000019
#                                   model_H841_k3d_iter_100__168         0.000019
#                                   model_H841_k3d_iter_100__192         0.000019
#                                   model_H841_k3d_iter_100__24          0.000019
#                                   model_H841_k3d_iter_100__48          0.000019
#                                   model_H841_k3d_iter_100__72          0.000019
#                                   model_H841_k3d_iter_100__96          0.000019
#
#                                                                 dip_y_intercept
# cell_line plate                   well_id
# NCIH1048  model_H841_k3d_iter_100 model_H841_k3d_iter_100__0           8.258736
#                                   model_H841_k3d_iter_100__120         8.258881
#                                   model_H841_k3d_iter_100__144         8.258832
#                                   model_H841_k3d_iter_100__168         8.258738
#                                   model_H841_k3d_iter_100__192         8.258881
#                                   model_H841_k3d_iter_100__24          8.258788
#                                   model_H841_k3d_iter_100__48          8.258882
#                                   model_H841_k3d_iter_100__72          8.258786
#                                   model_H841_k3d_iter_100__96          8.258830

# %%
d
# Out:
# HTS Dataset (1 drugs/combos, 1 cell lines)

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-49-d3267f9c76d1> in <module>
# ----> 1 plotAllDrugs(d)
#
# NameError: name 'plotAllDrugs' is not defined
